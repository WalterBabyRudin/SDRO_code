# %% [markdown]
# ### Results for Housing Dataset

# %%
from logging import Handler
import numpy as np
import matplotlib.pyplot as plt

cost_SG_hist = np.load("cost_SG_hist_housing.npy")
obj_SG_hist  = np.load("obj_SG_hist_housing.npy")

cost_MLMC_hist = np.load("cost_MLMC_hist_housing.npy")
obj_MLMC_hist  = np.load("obj_MLMC_hist_housing.npy")

cost_RTMLMC_hist = np.load("cost_RTMLMC_hist_housing.npy")
obj_RTMLMC_hist  = np.load("obj_RTMLMC_hist_housing.npy")

cost_RUMLMC_hist = np.load("cost_RUMLMC_hist_housing.npy")
obj_RUMLMC_hist  = np.load("obj_RUMLMC_hist_housing.npy")

cost_RRMLMC_hist = np.load("cost_RRMLMC_hist_housing.npy")
obj_RRMLMC_hist  = np.load("obj_RRMLMC_hist_housing.npy")

fig, axes = plt.subplots(figsize=(6,6))
axes.plot(cost_SG_hist, obj_SG_hist, label=r'SG', 
            linestyle = '-', marker = '^', markerfacecolor='none',
            color='#D55E00',ms=0.5,linewidth=2)

axes.plot(cost_MLMC_hist, obj_MLMC_hist, label=r'MLMC', 
            linestyle = '-', marker = 'd', markerfacecolor='none',
            color='#E69F00',ms=0.5,linewidth=2)

axes.plot(cost_RTMLMC_hist, obj_RTMLMC_hist, label=r'RT-MLMC', 
            linestyle = '-', marker = 'o', markerfacecolor='none',
            color='#56B4E9',ms=0.5,linewidth=2)


axes.plot(cost_RUMLMC_hist, obj_RUMLMC_hist, label=r'RU-MLMC', 
            linestyle = '--', marker = '*', markerfacecolor='none',
            color='#009E73',ms=0.5,linewidth=2)

axes.plot(cost_RRMLMC_hist, obj_RRMLMC_hist, label=r'RR-MLMC', 
            linestyle = '-', marker = 's', markerfacecolor='none',
            color='#CC79A7',ms=0.5,linewidth=2)
            
plt.xscale('log')

axes.grid(True, 'major')
axes.tick_params(labelsize=20)
axes.set_xlabel(r'Number of Generated Samples', fontsize=20)
axes.set_ylabel(r'SDRO Objective Values', fontsize=20)
leg = plt.legend(fontsize=15, loc="upper right")


plt.savefig('Obj_error_housing.png',bbox_inches="tight")

# %%
from logging import Handler
import numpy as np
import matplotlib.pyplot as plt

cost_SG_hist = np.load("cost_SG_hist_housing.npy")
residual_SG_hist  = np.load("residual_SG_hist_housing.npy")

cost_MLMC_hist = np.load("cost_MLMC_hist_housing.npy")
residual_MLMC_hist  = np.load("residual_MLMC_hist_housing.npy")

cost_RTMLMC_hist = np.load("cost_RTMLMC_hist_housing.npy")
residual_RTMLMC_hist  = np.load("residual_RTMLMC_hist_housing.npy")

cost_RUMLMC_hist = np.load("cost_RUMLMC_hist_housing.npy")
residual_RUMLMC_hist  = np.load("residual_RUMLMC_hist_housing.npy")

cost_RRMLMC_hist = np.load("cost_RRMLMC_hist_housing.npy")
residual_RRMLMC_hist  = np.load("residual_RRMLMC_hist_housing.npy")

fig, axes = plt.subplots(figsize=(6,6))
axes.plot(cost_SG_hist, residual_SG_hist, label=r'SG', 
            linestyle = '-', marker = '^', markerfacecolor='none',
            color='#D55E00',ms=0.5,linewidth=2)

axes.plot(cost_MLMC_hist, residual_MLMC_hist, label=r'MLMC', 
            linestyle = '-', marker = 'd', markerfacecolor='none',
            color='#E69F00',ms=0.5,linewidth=2)

axes.plot(cost_RTMLMC_hist, residual_RTMLMC_hist, label=r'RT-MLMC', 
            linestyle = '-', marker = 'o', markerfacecolor='none',
            color='#56B4E9',ms=0.5,linewidth=2)


axes.plot(cost_RUMLMC_hist, residual_RUMLMC_hist, label=r'RU-MLMC', 
            linestyle = '--', marker = '*', markerfacecolor='none',
            color='#009E73',ms=0.5,linewidth=2)

axes.plot(cost_RRMLMC_hist, residual_RRMLMC_hist, label=r'RR-MLMC', 
            linestyle = '-', marker = 's', markerfacecolor='none',
            color='#CC79A7',ms=0.5,linewidth=2)
            
plt.xscale('log')

axes.grid(True, 'major')
axes.tick_params(labelsize=20)
axes.set_xlabel(r'Number of Generated Samples', fontsize=20)
axes.set_ylabel(r'RMSE', fontsize=20)
leg = plt.legend(fontsize=15, loc="upper right")


plt.savefig('Residual_housing.png',bbox_inches="tight")

# %% [markdown]
#  ## Results for mg dataset

# %%
from logging import Handler
import numpy as np
import matplotlib.pyplot as plt

cost_SG_hist = np.load("cost_SG_hist_mg.npy")
obj_SG_hist  = np.load("obj_SG_hist_mg.npy")

cost_MLMC_hist = np.load("cost_MLMC_hist_mg.npy")
obj_MLMC_hist  = np.load("obj_MLMC_hist_mg.npy")

cost_RTMLMC_hist = np.load("cost_RTMLMC_hist_mg.npy")
obj_RTMLMC_hist  = np.load("obj_RTMLMC_hist_mg.npy")

cost_RUMLMC_hist = np.load("cost_RUMLMC_hist_mg.npy")
obj_RUMLMC_hist  = np.load("obj_RUMLMC_hist_mg.npy")

cost_RRMLMC_hist = np.load("cost_RRMLMC_hist_mg.npy")
obj_RRMLMC_hist  = np.load("obj_RRMLMC_hist_mg.npy")

fig, axes = plt.subplots(figsize=(6,6))
axes.plot(cost_SG_hist, obj_SG_hist, label=r'SG', 
            linestyle = '-', marker = '^', markerfacecolor='none',
            color='#D55E00',ms=0.5,linewidth=2)

axes.plot(cost_MLMC_hist, obj_MLMC_hist, label=r'MLMC', 
            linestyle = '-', marker = 'd', markerfacecolor='none',
            color='#E69F00',ms=0.5,linewidth=2)

axes.plot(cost_RTMLMC_hist, obj_RTMLMC_hist, label=r'RT-MLMC', 
            linestyle = '-', marker = 'o', markerfacecolor='none',
            color='#56B4E9',ms=0.5,linewidth=2)


axes.plot(cost_RUMLMC_hist, obj_RUMLMC_hist, label=r'RU-MLMC', 
            linestyle = '--', marker = '*', markerfacecolor='none',
            color='#009E73',ms=0.5,linewidth=2)

axes.plot(cost_RRMLMC_hist, obj_RRMLMC_hist, label=r'RR-MLMC', 
            linestyle = '-', marker = 's', markerfacecolor='none',
            color='#CC79A7',ms=0.5,linewidth=2)
            
plt.xscale('log')

axes.grid(True, 'major')
axes.tick_params(labelsize=20)
axes.set_xlabel(r'Number of Generated Samples', fontsize=20)
axes.set_ylabel(r'SDRO Objective Values', fontsize=20)
leg = plt.legend(fontsize=15, loc="upper right")


plt.savefig('Obj_error_mg.png',bbox_inches="tight")

# %%
from logging import Handler
import numpy as np
import matplotlib.pyplot as plt

cost_SG_hist = np.load("cost_SG_hist_mg.npy")
residual_SG_hist  = np.load("residual_SG_hist_mg.npy")

cost_MLMC_hist = np.load("cost_MLMC_hist_mg.npy")
residual_MLMC_hist  = np.load("residual_MLMC_hist_mg.npy")

cost_RTMLMC_hist = np.load("cost_RTMLMC_hist_mg.npy")
residual_RTMLMC_hist  = np.load("residual_RTMLMC_hist_mg.npy")

cost_RUMLMC_hist = np.load("cost_RUMLMC_hist_mg.npy")
residual_RUMLMC_hist  = np.load("residual_RUMLMC_hist_mg.npy")

cost_RRMLMC_hist = np.load("cost_RRMLMC_hist_mg.npy")
residual_RRMLMC_hist  = np.load("residual_RRMLMC_hist_mg.npy")

fig, axes = plt.subplots(figsize=(6,6))
axes.plot(cost_SG_hist, residual_SG_hist, label=r'SG', 
            linestyle = '-', marker = '^', markerfacecolor='none',
            color='#D55E00',ms=0.5,linewidth=2)

axes.plot(cost_MLMC_hist, residual_MLMC_hist, label=r'MLMC', 
            linestyle = '-', marker = 'd', markerfacecolor='none',
            color='#E69F00',ms=0.5,linewidth=2)

axes.plot(cost_RTMLMC_hist, residual_RTMLMC_hist, label=r'RT-MLMC', 
            linestyle = '-', marker = 'o', markerfacecolor='none',
            color='#56B4E9',ms=0.5,linewidth=2)

axes.plot(cost_RUMLMC_hist, residual_RUMLMC_hist, label=r'RU-MLMC', 
            linestyle = '--', marker = '*', markerfacecolor='none',
            color='#009E73',ms=0.5,linewidth=2)

axes.plot(cost_RRMLMC_hist, residual_RRMLMC_hist, label=r'RR-MLMC', 
            linestyle = '-', marker = 's', markerfacecolor='none',
            color='#CC79A7',ms=0.5,linewidth=2)
            
plt.xscale('log')

axes.grid(True, 'major')
axes.tick_params(labelsize=20)
axes.set_xlabel(r'Number of Generated Samples', fontsize=20)
axes.set_ylabel(r'RMSE', fontsize=20)
leg = plt.legend(fontsize=15, loc="upper right")


plt.savefig('Residual_mg.png',bbox_inches="tight")

# %% [markdown]
# ## Results for mpg dataset

# %%
from logging import Handler
import numpy as np
import matplotlib.pyplot as plt

cost_SG_hist = np.load("cost_SG_hist_mpg.npy")
obj_SG_hist  = np.load("obj_SG_hist_mpg.npy")

cost_MLMC_hist = np.load("cost_MLMC_hist_mpg.npy")
obj_MLMC_hist  = np.load("obj_MLMC_hist_mpg.npy")

cost_RTMLMC_hist = np.load("cost_RTMLMC_hist_mpg.npy")
obj_RTMLMC_hist  = np.load("obj_RTMLMC_hist_mpg.npy")

cost_RUMLMC_hist = np.load("cost_RUMLMC_hist_mpg.npy")
obj_RUMLMC_hist  = np.load("obj_RUMLMC_hist_mpg.npy")

cost_RRMLMC_hist = np.load("cost_RRMLMC_hist_mpg.npy")
obj_RRMLMC_hist  = np.load("obj_RRMLMC_hist_mpg.npy")

fig, axes = plt.subplots(figsize=(6,6))
axes.plot(cost_SG_hist, obj_SG_hist, label=r'SG', 
            linestyle = '-', marker = '^', markerfacecolor='none',
            color='#D55E00',ms=0.5,linewidth=2)

axes.plot(cost_MLMC_hist, obj_MLMC_hist, label=r'MLMC', 
            linestyle = '-', marker = 'd', markerfacecolor='none',
            color='#E69F00',ms=0.5,linewidth=2)

axes.plot(cost_RTMLMC_hist, obj_RTMLMC_hist, label=r'RT-MLMC', 
            linestyle = '-', marker = 'o', markerfacecolor='none',
            color='#56B4E9',ms=0.5,linewidth=2)


axes.plot(cost_RUMLMC_hist, obj_RUMLMC_hist, label=r'RU-MLMC', 
            linestyle = '--', marker = '*', markerfacecolor='none',
            color='#009E73',ms=0.5,linewidth=2)

axes.plot(cost_RRMLMC_hist, obj_RRMLMC_hist, label=r'RR-MLMC', 
            linestyle = '-', marker = 's', markerfacecolor='none',
            color='#CC79A7',ms=0.5,linewidth=2)
            
plt.xscale('log')

axes.grid(True, 'major')
axes.tick_params(labelsize=20)
axes.set_xlabel(r'Number of Generated Samples', fontsize=20)
axes.set_ylabel(r'SDRO Objective Values', fontsize=20)
leg = plt.legend(fontsize=15, loc="upper right")


plt.savefig('Obj_error_mpg.png',bbox_inches="tight")

# %%
from logging import Handler
import numpy as np
import matplotlib.pyplot as plt

cost_SG_hist = np.load("cost_SG_hist_mpg.npy")
residual_SG_hist  = np.load("residual_SG_hist_mpg.npy")

cost_MLMC_hist = np.load("cost_MLMC_hist_mpg.npy")
residual_MLMC_hist  = np.load("residual_MLMC_hist_mpg.npy")

cost_RTMLMC_hist = np.load("cost_RTMLMC_hist_mpg.npy")
residual_RTMLMC_hist  = np.load("residual_RTMLMC_hist_mpg.npy")

cost_RUMLMC_hist = np.load("cost_RUMLMC_hist_mpg.npy")
residual_RUMLMC_hist  = np.load("residual_RUMLMC_hist_mpg.npy")

cost_RRMLMC_hist = np.load("cost_RRMLMC_hist_mpg.npy")
residual_RRMLMC_hist  = np.load("residual_RRMLMC_hist_mpg.npy")

fig, axes = plt.subplots(figsize=(6,6))
axes.plot(cost_SG_hist, residual_SG_hist, label=r'SG', 
            linestyle = '-', marker = '^', markerfacecolor='none',
            color='#D55E00',ms=0.5,linewidth=2)

axes.plot(cost_MLMC_hist, residual_MLMC_hist, label=r'MLMC', 
            linestyle = '-', marker = 'd', markerfacecolor='none',
            color='#E69F00',ms=0.5,linewidth=2)

axes.plot(cost_RTMLMC_hist, residual_RTMLMC_hist, label=r'RT-MLMC', 
            linestyle = '-', marker = 'o', markerfacecolor='none',
            color='#56B4E9',ms=0.5,linewidth=2)

axes.plot(cost_RUMLMC_hist, residual_RUMLMC_hist, label=r'RU-MLMC', 
            linestyle = '--', marker = '*', markerfacecolor='none',
            color='#009E73',ms=0.5,linewidth=2)

axes.plot(cost_RRMLMC_hist, residual_RRMLMC_hist, label=r'RR-MLMC', 
            linestyle = '-', marker = 's', markerfacecolor='none',
            color='#CC79A7',ms=0.5,linewidth=2)
            
plt.xscale('log')

axes.grid(True, 'major')
axes.tick_params(labelsize=20)
axes.set_xlabel(r'Number of Generated Samples', fontsize=20)
axes.set_ylabel(r'RMSE', fontsize=20)
leg = plt.legend(fontsize=15, loc="upper right")


plt.savefig('Residual_mpg.png',bbox_inches="tight")
